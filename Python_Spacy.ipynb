# %% [markdown]
# <a href="https://colab.research.google.com/github/IgorMoraes07/Treinos_Python/blob/main/Python_Spacy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Instalando o spaCy e baixando o modelo em Português
# !pip install -U spacy
# !python -m spacy download pt_core_news_sm
# Out:
# ...
# 2023-07-06 19:57:36.348414: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-06 19:57:37.522045: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 70.7 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('pt_core_news_sm')

# %%
#Importando a biblioteca
import spacy

# %%
#Carregando o modelo de linguagem
nlp = spacy.load("pt_core_news_sm")

# %%
#Processando todas as linhas
text = ("Título do jogo: Chronos: Destino em Três Épocas"
      "Enredo:"
      "Em Chronos: Destino em Três Épocas, você assume o papel de Alex Grant, um arqueólogo renomado e viajante do tempo. O jogo se passa em três épocas diferentes: a Idade Média, a Revolução Industrial e o Futuro Distópico. O objetivo principal é desvendar um mistério envolvendo uma antiga sociedade secreta que tem o poder de controlar o tempo e está determinada a alterar a história para seu próprio benefício."
      "A história começa quando Alex descobre um artefato misterioso que o transporta para a Idade Média. Lá, ele percebe que a história está sendo modificada e que o futuro está em risco. Para evitar que isso aconteça, Alex deve encontrar os membros restantes da sociedade secreta e impedir que eles manipulem o fluxo do tempo."
      "Ao explorar a Idade Média, o jogador enfrentará desafios dos cavaleiros medievais, magos e criaturas mitológicas. Alex encontrará personagens históricos reais enquanto desvenda enigmas e coleta artefatos que o ajudarão a desvendar a conspiração."
      "No entanto, a aventura não para por aí. Com a ajuda de um dispositivo de viagem no tempo, Alex salta para a era da Revolução Industrial. Aqui, as máquinas movidas a vapor e a urbanização em massa dão uma nova dimensão ao gameplay. Alex enfrentará magnatas gananciosos e sociedades secretas do submundo, enquanto desenterra segredos que podem mudar o curso da história."
      "Finalmente, o jogador será levado para o ano 2223, onde um futuro distópico assombra a humanidade. Mega-corporações dominam o mundo, e a tecnologia avançada criou uma sociedade opressora. Alex precisa enfrentar androides de combate e hackers cibernéticos enquanto mergulha nas profundezas da conspiração que ameaça a própria existência humana."
      "Ao longo das três épocas, o jogador deve descobrir pistas, resolver quebra-cabeças, combater inimigos e tomar decisões que afetarão diretamente o curso do enredo. A trama se desenrola em sequências cinematográficas emocionantes e revela segredos obscuros sobre a sociedade secreta e sua verdadeira intenção de controlar o fluxo do tempo."
      "Chronos: Destino em Três Épocas é uma jornada emocionante que combina elementos de ficção científica, aventura e história, enquanto mergulha na mente de Alex Grant e em sua luta para salvar a humanidade. Neste jogo, o destino está em suas mãos.")
doc = nlp(text)

# %%
#Teste 1 de tokenização de conteúdo
for token in doc:
    print(token.text, token.pos_, token.dep_)
# Out:
# Título NOUN ROOT
# do ADP case
# jogo NOUN nmod
# : PUNCT punct
# Chronos NOUN ROOT
# : PUNCT punct
# Destino PROPN appos
# em ADP case
# Três PROPN nmod
# ÉpocasEnredo PROPN flat
# : PUNCT punct
# Em ADP case
# Chronos PROPN obl
# : PUNCT punct
# Destino PROPN nmod
# em ADP case
# Três PROPN nmod
# Épocas PROPN flat:name
# , PUNCT punct
# você PRON nsubj
# assume VERB ROOT
# o DET det
# papel NOUN obj
# de ADP case
# Alex PROPN nmod
# Grant PROPN flat:name
# , PUNCT punct
# um DET det
# arqueólogo NOUN appos
# renomado VERB acl
# e CCONJ cc
# viajante ADJ conj
# do ADP case
# tempo NOUN obl
# . PUNCT punct
# O DET det
# jogo NOUN nsubj
# se PRON expl
# passa VERB ROOT
# em ADP case
# três NUM nummod
# épocas NOUN obl
# diferentes ADJ amod
# : PUNCT punct
# a DET det
# Idade PROPN appos
# Média PROPN flat:name
# , PUNCT punct
# a DET det
# Revolução PROPN appos
# Industrial PROPN flat:name
# e CCONJ flat:name
# o DET flat:name
# Futuro PROPN flat:name
# Distópico PROPN flat:name
# ...

# %%
#Teste 2 de tokenização de conteúdo
print("Noun phrases:", [chunk.text for chunk in doc.noun_chunks])
print("Verbs:", [token.lemma_ for token in doc if token.pos_ == "VERB"])
# Out:
# Noun phrases: ['Título', 'jogo', 'Chronos', 'Destino', 'Três ÉpocasEnredo', 'Chronos', 'Destino', 'Três Épocas', 'você', 'o papel', 'Alex Grant', ', um arqueólogo', 'tempo', 'O jogo', 'três épocas diferentes', ': a Idade Média', ', a Revolução Industrial e o Futuro Distópico', 'O objetivo principal', 'um mistério', 'uma antiga sociedade secreta', 'que', 'o poder', 'o tempo', 'a história', 'seu próprio benefício', 'A história', 'Alex', 'um artefato misterioso', 'a Idade Média', 'ele', 'a história', 'o futuro', 'isso', 'Alex', 'os membros restantes', 'sociedade secreta', 'eles', 'o fluxo', 'tempo', 'Idade Média', 'o jogador', 'desafios', 'cavaleiros medievais, magos', 'criaturas', 'Alex', 'personagens históricos', 'enigmas', 'artefatos', 'que', 'o', 'a conspiração', 'entanto, a aventura', 'a ajuda', 'um dispositivo', 'viagem', 'tempo', ', Alex salta para a era da Revolução Industrial', 'as máquinas', 'a urbanização', 'massa', 'uma nova dimensão', 'gameplay', 'Alex', 'magnatas ganancios
# ...

# %%
#Buscando entidades nomeadas, frases and conceitos
for entity in doc.ents:
    print(entity.text, entity.label_)
# Out:
# Chronos MISC
# Destino em Três ÉpocasEnredo MISC
# Chronos LOC
# Destino em Três Épocas MISC
# Alex Grant PER
# Idade Média MISC
# Revolução Industrial e o Futuro Distópico MISC
# Alex MISC
# Idade Média MISC
# Alex PER
# Idade Média MISC
# Alex MISC
# Alex PER
# Revolução Industrial MISC
# Alex MISC
# Alex MISC
# Chronos LOC
# Destino em Três Épocas MISC
# Alex Grant PER
